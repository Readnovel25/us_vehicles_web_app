# %% [markdown]
# # Sprint 4 - Software Development Tools Project
# # Exploratory Data Analysis

# %% [markdown]
# # 1. Introduction
# ## 1.1 Background
# Using the `vehicles_us` dataset, this project aims to provide additional practice on common software engineering tasks learned in this sprint. Develop and deploy a web application to a cloud service, Render, in this case.

# %% [markdown]
# ## 1.2 Stages
# There is only one dataset in this project, `../vehicles_us.csv`, for this project.
#
# To analyze this dataset, the following steps will be followed:
# 1. Data Overview
# 2. Data Preprocessing
# 3. Data Analysis

# %% [markdown]
# # 2 Data Overview
# Import the libraries to be used on this project.

# %%
# Loading all the libraries
import pandas as pd
from scipy import stats
import streamlit as st

# %% [markdown]
# Open the dataset in a dataframe, `vehicles_df`.

# %%
# Load the data
vehicles_df = pd.read_csv('../vehicles_us.csv')

# Show dataframe
vehicles_df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV         NaN     1.0  2018-06-23           19
# 1        automatic  pickup       white     1.0  2018-10-19           50
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup         NaN     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan         NaN     NaN  2018-06-05           10
#
# [51525 rows x 13 columns]

# %% [markdown]
# # 3 Data Preprocessing
# Explore the dataset to get the initial understanding of the data. Do necessary corrections.

# %%
# Get basic info
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
# Add a brand column to the dataframe
vehicles_df['brand'] = vehicles_df['model'].apply(lambda x: x.split()[0])

# Insert new column at index 3 so it shows after model in dataframe
vehicles_df.insert(3, 'brand', vehicles_df.pop('brand'))

# Show dataframe
vehicles_df
# Out:
#        price  model_year           model     brand  condition  cylinders fuel  \
# 0       9400      2011.0          bmw x5       bmw       good        6.0  gas
# 1      25500         NaN      ford f-150      ford       good        6.0  gas
# 2       5500      2013.0  hyundai sonata   hyundai   like new        4.0  gas
# 3       1500      2003.0      ford f-150      ford       fair        8.0  gas
# 4      14900      2017.0    chrysler 200  chrysler  excellent        4.0  gas
# ...      ...         ...             ...       ...        ...        ...  ...
# 51520   9249      2013.0   nissan maxima    nissan   like new        6.0  gas
# 51521   2700      2002.0     honda civic     honda    salvage        4.0  gas
# 51522   3950      2009.0  hyundai sonata   hyundai  excellent        4.0  gas
# 51523   7455      2013.0  toyota corolla    toyota       good        4.0  gas
# 51524   6300      2014.0   nissan altima    nissan       good        4.0  gas
#
#        odometer transmission    type paint_color  is_4wd date_posted  \
# 0      145000.0    automatic     SUV         NaN     1.0  2018-06-23
# 1       88705.0    automatic  pickup       white     1.0  2018-10-19
# 2      110000.0    automatic   sedan         red     NaN  2019-02-07
# 3           NaN    automatic  pickup         NaN     NaN  2019-03-22
# 4       80903.0    automatic   sedan       black     NaN  2019-04-02
# ...         ...          ...     ...         ...     ...         ...
# 51520   88136.0    automatic   sedan       black     NaN  2018-10-03
# 51521  181500.0    automatic   sedan       white     NaN  2018-11-14
# 51522  128000.0    automatic   sedan        blue     NaN  2018-11-15
# 51523  139573.0    automatic   sedan       black     NaN  2018-07-02
# 51524       NaN    automatic   sedan         NaN     NaN  2018-06-05
#
#        days_listed
# 0               19
# 1               50
# 2               79
# 3                9
# 4               28
# ...            ...
# 51520           37
# 51521           22
# 51522           32
# 51523           71
# 51524           10
#
# [51525 rows x 14 columns]

# %% [markdown]
# I added a `'brand'`column to capture the manufacturer of each model for further analysis down the line. There are some missing values that will be addressed in the next section.

# %% [markdown]
# ## 3.1 Missing Values
# Check for any missing values and fill them appropriately.

# %%
# Check for missing values
vehicles_df.isna().sum()
# Out:
# price               0
# model_year       3619
# model               0
# brand               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %% [markdown]
# Let's fill the missing values in the `'is_4wd'` column first.

# %%
# Let's ensure that all the missing values in the 'is_4wd' column are supposed to be 0
# Check the unique values in this column
vehicles_df['is_4wd'].unique()
# Out:
# array([ 1., nan])

# %%
# Replace the missing values in 'is_4wd' with 0 and change type to boolean
vehicles_df['is_4wd'] = vehicles_df['is_4wd'].fillna(0).astype(bool)

# Check for missing values
vehicles_df.isna().sum()
# Out:
# price              0
# model_year      3619
# model              0
# brand              0
# condition          0
# cylinders       5260
# fuel               0
# odometer        7892
# transmission       0
# type               0
# paint_color     9267
# is_4wd             0
# date_posted        0
# days_listed        0
# dtype: int64

# %% [markdown]
# There were missing values in the `'is_4wd'` column. Using the `unique` method on this column, I was able to determine that the missing values were probably indicating the value 0 so I filled the missing values with 0.

# %% [markdown]
# Let's replace the missing values in the `'paint_color'`, `'cylinders'`, and `'model_year'` columns with the mode of each by model. The median wouldn't make sense for these columns as they are categorical in nature despite the `'cylinders'`, and `'model_year'` columns being numerical.

# %%
# Replace missing paint colors with the most frequent value for each model
vehicles_df['paint_color'] = vehicles_df.groupby('model')['paint_color'].transform(lambda x: x.fillna(x.mode()[0]))

# Check for missing values
vehicles_df.isna().sum()
# Out:
# price              0
# model_year      3619
# model              0
# brand              0
# condition          0
# cylinders       5260
# fuel               0
# odometer        7892
# transmission       0
# type               0
# paint_color        0
# is_4wd             0
# date_posted        0
# days_listed        0
# dtype: int64

# %%
# Replace missing cylinders with the most frequent value for each model
vehicles_df['cylinders'] = vehicles_df.groupby('model')['cylinders'].transform(lambda x: x.fillna(x.mode()[0]))

# Check for missing values
vehicles_df.isna().sum()
# Out:
# price              0
# model_year      3619
# model              0
# brand              0
# condition          0
# cylinders          0
# fuel               0
# odometer        7892
# transmission       0
# type               0
# paint_color        0
# is_4wd             0
# date_posted        0
# days_listed        0
# dtype: int64

# %%
# Replace missing model years with the most frequent value for each model
vehicles_df['model_year'] = vehicles_df.groupby('model')['model_year'].transform(lambda x: x.fillna(x.mode()[0]))

# Check for missing values
vehicles_df.isna().sum()
# Out:
# price              0
# model_year         0
# model              0
# brand              0
# condition          0
# cylinders          0
# fuel               0
# odometer        7892
# transmission       0
# type               0
# paint_color        0
# is_4wd             0
# date_posted        0
# days_listed        0
# dtype: int64

# %% [markdown]
# Finally, let's fill the `'odometer'` column with the median value of each by model.

# %%
# 
vehicles_df.groupby('model')['odometer'].median()
# Out:
# model
# acura tl             141000.0
# bmw x5               108500.0
# buick enclave        113728.0
# cadillac escalade    129176.0
# chevrolet camaro      62655.5
#                        ...
# toyota sienna        140715.0
# toyota tacoma        125000.0
# toyota tundra        120500.0
# volkswagen jetta     107000.0
# volkswagen passat     84905.0
# Name: odometer, Length: 100, dtype: float64

# %%
# Replace missing odometer values with the median odometer value for each model
vehicles_df['odometer'] = vehicles_df.groupby('model')['odometer'].transform(lambda x: x.fillna(x.median()))

# Check for missing values
vehicles_df.isna().sum()
# Out:
# c:\Users\shoul\OneDrive\Documents\TripleTen_Data_Science_Bootcamp\Sprint_4\SDT_Final_Project\us_vehicles_web_app\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# price            0
# model_year       0
# model            0
# brand            0
# condition        0
# cylinders        0
# fuel             0
# odometer        41
# transmission     0
# type             0
# paint_color      0
# is_4wd           0
# date_posted      0
# days_listed      0
# dtype: int64

# %% [markdown]
# Oops, it looks like this approach did not eliminate all the missing values in the `'odometer'` column so let's take a look at the remaining missing values.

# %%
# Check which models have no odometer value
vehicles_df[vehicles_df['odometer'].isna()]['model'].value_counts()
# Out:
# model
# mercedes-benz benze sprinter 2500    41
# Name: count, dtype: int64

# %%
# View all the models in the brand mercedes-benz
vehicles_df[vehicles_df['brand'] == 'mercedes-benz']
# Out:
#        price  model_year                              model          brand  \
# 42     34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 1642   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 2232   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 2731   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 4149   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 4681   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 5681   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 8975   34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 10600  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 11541  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 11916  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 14796  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 14871  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 17473  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 17493  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 18103  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 18811  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 19877  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 22002  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 23445  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 25982  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 26905  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 27345  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 31895  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 34466  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 34621  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 34905  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 36088  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 36518  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 38204  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 39904  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 40524  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 42116  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 42393  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 42503  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 44327  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 44698  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 48012  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 48483  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 50547  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
# 50624  34900      2013.0  mercedes-benz benze sprinter 2500  mercedes-benz
#
#        condition  cylinders    fuel  odometer transmission type paint_color  \
# 42     excellent        6.0  diesel       NaN    automatic  van       black
# 1642   excellent        6.0  diesel       NaN    automatic  van       black
# 2232   excellent        6.0  diesel       NaN    automatic  van       black
# 2731   excellent        6.0  diesel       NaN    automatic  van       black
# 4149   excellent        6.0  diesel       NaN    automatic  van       black
# 4681   excellent        6.0  diesel       NaN    automatic  van       black
# 5681   excellent        6.0  diesel       NaN    automatic  van       black
# 8975   excellent        6.0  diesel       NaN    automatic  van       black
# 10600  excellent        6.0  diesel       NaN    automatic  van       black
# 11541  excellent        6.0  diesel       NaN    automatic  van       black
# 11916  excellent        6.0  diesel       NaN    automatic  van       black
# 14796  excellent        6.0  diesel       NaN    automatic  van       black
# 14871  excellent        6.0  diesel       NaN    automatic  van       black
# 17473  excellent        6.0  diesel       NaN    automatic  van       black
# 17493  excellent        6.0  diesel       NaN    automatic  van       black
# 18103  excellent        6.0  diesel       NaN    automatic  van       black
# 18811  excellent        6.0  diesel       NaN    automatic  van       black
# 19877  excellent        6.0  diesel       NaN    automatic  van       black
# 22002  excellent        6.0  diesel       NaN    automatic  van       black
# 23445  excellent        6.0  diesel       NaN    automatic  van       black
# 25982  excellent        6.0  diesel       NaN    automatic  van       black
# 26905  excellent        6.0  diesel       NaN    automatic  van       black
# 27345  excellent        6.0  diesel       NaN    automatic  van       black
# 31895  excellent        6.0  diesel       NaN    automatic  van       black
# 34466  excellent        6.0  diesel       NaN    automatic  van       black
# 34621  excellent        6.0  diesel       NaN    automatic  van       black
# 34905  excellent        6.0  diesel       NaN    automatic  van       black
# 36088  excellent        6.0  diesel       NaN    automatic  van       black
# 36518  excellent        6.0  diesel       NaN    automatic  van       black
# 38204  excellent        6.0  diesel       NaN    automatic  van       black
# 39904  excellent        6.0  diesel       NaN    automatic  van       black
# 40524  excellent        6.0  diesel       NaN    automatic  van       black
# 42116  excellent        6.0  diesel       NaN    automatic  van       black
# 42393  excellent        6.0  diesel       NaN    automatic  van       black
# 42503  excellent        6.0  diesel       NaN    automatic  van       black
# 44327  excellent        6.0  diesel       NaN    automatic  van       black
# 44698  excellent        6.0  diesel       NaN    automatic  van       black
# 48012  excellent        6.0  diesel       NaN    automatic  van       black
# 48483  excellent        6.0  diesel       NaN    automatic  van       black
# 50547  excellent        6.0  diesel       NaN    automatic  van       black
# 50624  excellent        6.0  diesel       NaN    automatic  van       black
#
#        is_4wd date_posted  days_listed
# 42      False  2019-01-15           16
# 1642    False  2018-12-04           36
# 2232    False  2018-08-23           70
# 2731    False  2019-04-12           31
# 4149    False  2018-10-12           28
# 4681    False  2018-10-02           32
# 5681    False  2018-12-11           34
# 8975    False  2018-09-24           45
# 10600   False  2018-09-16           47
# 11541   False  2018-05-28           24
# 11916   False  2019-02-19            7
# 14796   False  2018-07-29            1
# 14871   False  2018-10-09           16
# 17473   False  2019-03-23           34
# 17493   False  2019-01-28           99
# 18103   False  2019-01-21           87
# 18811   False  2018-08-03           52
# 19877   False  2018-10-16           44
# 22002   False  2018-10-20           87
# 23445   False  2018-06-13           20
# 25982   False  2018-06-06           37
# 26905   False  2018-10-28           70
# 27345   False  2019-04-18           29
# 31895   False  2018-05-21           59
# 34466   False  2019-04-09           80
# 34621   False  2018-10-12           36
# 34905   False  2019-03-09           13
# 36088   False  2018-08-25           60
# 36518   False  2018-05-26           34
# 38204   False  2018-10-06           24
# 39904   False  2019-02-13            7
# 40524   False  2019-04-06           41
# 42116   False  2018-05-18           50
# 42393   False  2018-10-28           14
# 42503   False  2018-05-28           14
# 44327   False  2019-03-20           51
# 44698   False  2019-01-16           17
# 48012   False  2018-10-14           19
# 48483   False  2018-08-19           27
# 50547   False  2018-12-28           49
# 50624   False  2019-04-13           40

# %%
# Confirm that only the benze sprinter model is in the mercedes-benz to see if we could fill with median value from brand
vehicles_df[vehicles_df['brand'] == 'mercedes-benz']['model'].value_counts()
# Out:
# model
# mercedes-benz benze sprinter 2500    41
# Name: count, dtype: int64

# %% [markdown]
# The mercedes-benz benze sprinter 2500 does not have any odometer value entered so let's fill the missing values with the median odometer value for 6.0 cylinders cars.

# %%
# Replace missing odometer values with the median odometer value for each cylinder type
vehicles_df['odometer'] = vehicles_df.groupby('cylinders')['odometer'].transform(lambda x: x.fillna(x.median()))

# Check for missing values
vehicles_df.isna().sum()
# Out:
# price           0
# model_year      0
# model           0
# brand           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %% [markdown]
# All missing values have now been filled so let's take a look at any duplicate values implicit or explicit that we can find in our dataset.

# %% [markdown]
# ## 3.2 Duplicate Values
# Check for fully duplicate rows or duplicates in the `'model'` and `'model_year'` columns.

# %%
# Check for fully duplicate rows
vehicles_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are no fully duplicate rows that can be found at the moment. However, let's further categorize our dataset by grouping by the `'brand'` column.

# %% [markdown]
# Histogram of fuel vs model_year
# Scatterplot of price vs manufacturer
